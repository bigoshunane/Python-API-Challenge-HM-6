# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_longs and cities
lat_longs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
longs = np.random.uniform(long_range[0], long_range[1], size=1500)
lat_longs = zip(lats, longs)

# Identify nearest city for each lat, long combination
for lat_long in lat_longs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#setting up lists to hold return infos and set up counters

country_name = []
city_name = []
cloud = []
date = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = []
index_counter = 0
set_counter = 1

#Performing API calls
print ("_______________________________")
print("Data Retrieval starts ")
print ("_______________________________") 

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop matching city names with city list using enumerate method

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloud.append(response["clouds"]["all"])
        country_name.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. skipping to next........")
        
print("________________________________")
print("Data Retrieval Complets")
print("________________________________")
# Out:
# _______________________________
# Data Retrieval starts
# _______________________________
# Processing Record 1 of Set 1 : tiksi
# Processing Record 2 of Set 1 : puerto carreno
# Processing Record 3 of Set 1 : richards bay
# Processing Record 4 of Set 1 : rikitea
# Processing Record 5 of Set 1 : port alfred
# City not found. skipping to next........
# Processing Record 6 of Set 1 : kapit
# Processing Record 7 of Set 1 : badiraguato
# Processing Record 8 of Set 1 : mandera
# Processing Record 9 of Set 1 : muros
# City not found. skipping to next........
# City not found. skipping to next........
# Processing Record 10 of Set 1 : haines junction
# Processing Record 11 of Set 1 : tuktoyaktuk
# Processing Record 12 of Set 1 : cherskiy
# Processing Record 13 of Set 1 : kaitangata
# Processing Record 14 of Set 1 : busselton
# Processing Record 15 of Set 1 : new norfolk
# Processing Record 16 of Set 1 : barrow
# Processing Record 17 of Set 1 : severnoye
# Processing Record 18 of Set 1 : ushuaia
# Processing Record 19 of Set 1 : kapaa
# Processing Record 20 of Set 1 : namibe
# Processing Record 21 of Set 1 : ossora
# Processing Record 22 of Set 1 : punta arenas
# Processing Record 23 of Set 1 : albany
# Processing Record 24 of Set 1 : faanui
# Processing Record 25 of Set 1 : bunia
# Processing Record 26 of Set 1 : bredasdorp
# Processing Record 27 of Set 1 : qaanaaq
# Processing Record 28 of Set 1 : georgetown
# Processing Record 29 of Set 1 : atuona
# City not found. skipping to next........
# City not found. skipping to next........
# Processing Record 30 of Set 1 : mataura
# Processing Record 31 of Set 1 : chokurdakh
# Processing Record 32 of Set 1 : geraldton
# Processing Record 33 of Set 1 : srednekolymsk
# Processing Record 34 of Set 1 : bud
# Processing Record 35 of Set 1 : isangel
# Processing Record 36 of Set 1 : avarua
# Processing Record 37 of Set 1 : port macquarie
# Processing Record 38 of Set 1 : ballitoville
# Processing Record 39 of Set 1 : opuwo
# Processing Record 40 of Set 1 : hasaki
# Processing Record 41 of Set 1 : komsomolskiy
# Processing Record 42 of Set 1 : ilulissat
# City not found. skipping to next........
# Processing Record 43 of Set 1 : siderno
# Processing Record 44 of Set 1 : yellowknife
# Processing Record 45 of Set 1 : hobyo
# Processing Record 46 of Set 1 : okhotsk
# Processing Record 47 of Set 1 : butaritari
# Processing Record 48 of Set 1 : lalmohan
# Processing Record 49 of Set 1 : cortez
# Processing Record 50 of Set 1 : hithadhoo
# Processing Record 0 of Set 2 : iqaluit
# Processing Record 1 of Set 2 : whitehorse
# Processing Record 2 of Set 2 : tuy hoa
# Processing Record 3 of Set 2 : macherla
# City not found. skipping to next........
# Processing Record 4 of Set 2 : kalmunai
# Processing Record 5 of Set 2 : chicama
# Processing Record 6 of Set 2 : beasain
# Processing Record 7 of Set 2 : pevek
# Processing Record 8 of Set 2 : la ronge
# Processing Record 9 of Set 2 : ponca city
# Processing Record 10 of Set 2 : vestmannaeyjar
# Processing Record 11 of Set 2 : buala
# Processing Record 12 of Set 2 : ambon
# Processing Record 13 of Set 2 : houma
# Processing Record 14 of Set 2 : qaqortoq
# City not found. skipping to next........
# Processing Record 15 of Set 2 : hobart
# Processing Record 16 of Set 2 : mahebourg
# Processing Record 17 of Set 2 : upernavik
# Processing Record 18 of Set 2 : hilo
# Processing Record 19 of Set 2 : meulaboh
# City not found. skipping to next........
# Processing Record 20 of Set 2 : port blair
# Processing Record 21 of Set 2 : baykit
# Processing Record 22 of Set 2 : kodiak
# Processing Record 23 of Set 2 : toccoa
# Processing Record 24 of Set 2 : batagay-alyta
# City not found. skipping to next........
# Processing Record 25 of Set 2 : hermanus
# Processing Record 26 of Set 2 : kidodi
# Processing Record 27 of Set 2 : kahului
# Processing Record 28 of Set 2 : kindberg
# Processing Record 29 of Set 2 : lanzhou
# Processing Record 30 of Set 2 : san cristobal
# Processing Record 31 of Set 2 : bengkulu
# Processing Record 32 of Set 2 : maceio
# City not found. skipping to next........
# Processing Record 33 of Set 2 : ewa beach
# Processing Record 34 of Set 2 : hamilton
# Processing Record 35 of Set 2 : dunedin
# Processing Record 36 of Set 2 : vaini
# Processing Record 37 of Set 2 : arraial do cabo
# Processing Record 38 of Set 2 : khatanga
# Processing Record 39 of Set 2 : lavrentiya
# Processing Record 40 of Set 2 : castro
# Processing Record 41 of Set 2 : jamestown
# Processing Record 42 of Set 2 : guerrero negro
# Processing Record 43 of Set 2 : trairi
# Processing Record 44 of Set 2 : nouakchott
# Processing Record 45 of Set 2 : oranjemund
# Processing Record 46 of Set 2 : wewak
# Processing Record 47 of Set 2 : peterongan
# Processing Record 48 of Set 2 : kalabo
# Processing Record 49 of Set 2 : tuatapere
# Processing Record 50 of Set 2 : adrar
# Processing Record 0 of Set 3 : beausejour
# Processing Record 1 of Set 3 : elat
# Processing Record 2 of Set 3 : sinegorsk
# Processing Record 3 of Set 3 : cape town
# Processing Record 4 of Set 3 : akureyri
# Processing Record 5 of Set 3 : itoman
# Processing Record 6 of Set 3 : karlskrona
# Processing Record 7 of Set 3 : denpasar
# Processing Record 8 of Set 3 : treinta y tres
# Processing Record 9 of Set 3 : maniitsoq
# Processing Record 10 of Set 3 : vostok
# Processing Record 11 of Set 3 : kruisfontein
# Processing Record 12 of Set 3 : cidreira
# Processing Record 13 of Set 3 : carnarvon
# Processing Record 14 of Set 3 : tabou
# Processing Record 15 of Set 3 : thompson
# Processing Record 16 of Set 3 : pujili
# Processing Record 17 of Set 3 : kendari
# Processing Record 18 of Set 3 : severo-kurilsk
# Processing Record 19 of Set 3 : mathbaria
# Processing Record 20 of Set 3 : manta
# Processing Record 21 of Set 3 : mar del plata
# Processing Record 22 of Set 3 : lunenburg
# Processing Record 23 of Set 3 : port hedland
# Processing Record 24 of Set 3 : chenghai
# Processing Record 25 of Set 3 : bluff
# Processing Record 26 of Set 3 : malangwa
# Processing Record 27 of Set 3 : pokhara
# Processing Record 28 of Set 3 : mecca
# Processing Record 29 of Set 3 : fez
# Processing Record 30 of Set 3 : sur
# Processing Record 31 of Set 3 : coihaique
# Processing Record 32 of Set 3 : moose factory
# Processing Record 33 of Set 3 : khudumelapye
# Processing Record 34 of Set 3 : warmbad
# Processing Record 35 of Set 3 : saldanha
# Processing Record 36 of Set 3 : verkhovyna
# Processing Record 37 of Set 3 : ponta do sol
# Processing Record 38 of Set 3 : zhuanghe
# Processing Record 39 of Set 3 : blagoyevo
# Processing Record 40 of Set 3 : nanortalik
# Processing Record 41 of Set 3 : vardo
# Processing Record 42 of Set 3 : quatre cocos
# Processing Record 43 of Set 3 : saint george
# Processing Record 44 of Set 3 : torbay
# Processing Record 45 of Set 3 : victoria
# City not found. skipping to next........
# Processing Record 46 of Set 3 : kavaratti
# Processing Record 47 of Set 3 : abu dhabi
# Processing Record 48 of Set 3 : te anau
# Processing Record 49 of Set 3 : narsaq
# Processing Record 50 of Set 3 : verkhnevilyuysk
# Processing Record 0 of Set 4 : tarjan
# Processing Record 1 of Set 4 : olafsvik
# Processing Record 2 of Set 4 : misratah
# Processing Record 3 of Set 4 : sire
# Processing Record 4 of Set 4 : zverinogolovskoye
# City not found. skipping to next........
# Processing Record 5 of Set 4 : sawakin
# Processing Record 6 of Set 4 : kytmanovo
# Processing Record 7 of Set 4 : genhe
# Processing Record 8 of Set 4 : kuvandyk
# Processing Record 9 of Set 4 : koumac
# Processing Record 10 of Set 4 : shimoda
# Processing Record 11 of Set 4 : lisakovsk
# Processing Record 12 of Set 4 : hutang
# City not found. skipping to next........
# Processing Record 13 of Set 4 : lebu
# Processing Record 14 of Set 4 : provideniya
# Processing Record 15 of Set 4 : santiago de cao
# Processing Record 16 of Set 4 : saint-philippe
# Processing Record 17 of Set 4 : vila velha
# Processing Record 18 of Set 4 : inhambane
# Processing Record 19 of Set 4 : ixtapa
# City not found. skipping to next........
# Processing Record 20 of Set 4 : ziyang
# Processing Record 21 of Set 4 : montrose
# Processing Record 22 of Set 4 : abashiri
# Processing Record 23 of Set 4 : bonnyville
# Processing Record 24 of Set 4 : usinsk
# Processing Record 25 of Set 4 : saskylakh
# Processing Record 26 of Set 4 : mujiayingzi
# Processing Record 27 of Set 4 : kirakira
# Processing Record 28 of Set 4 : puerto ayora
# City not found. skipping to next........
# Processing Record 29 of Set 4 : saryg-sep
# Processing Record 30 of Set 4 : dikson
# Processing Record 31 of Set 4 : inongo
# Processing Record 32 of Set 4 : aklavik
# Processing Record 33 of Set 4 : necochea
# Processing Record 34 of Set 4 : sibu
# Processing Record 35 of Set 4 : altukhovo
# Processing Record 36 of Set 4 : teguise
# Processing Record 37 of Set 4 : esmeraldas
# Processing Record 38 of Set 4 : marsa matruh
# Processing Record 39 of Set 4 : caraquet
# Processing Record 40 of Set 4 : arlit
# City not found. skipping to next........
# Processing Record 41 of Set 4 : sao filipe
# Processing Record 42 of Set 4 : padang
# Processing Record 43 of Set 4 : eyl
# Processing Record 44 of Set 4 : wasco
# Processing Record 45 of Set 4 : uvinza
# Processing Record 46 of Set 4 : port lincoln
# Processing Record 47 of Set 4 : oeiras do para
# Processing Record 48 of Set 4 : requena
# Processing Record 49 of Set 4 : atakpame
# Processing Record 50 of Set 4 : east london
# Processing Record 0 of Set 5 : petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 : chuy
# Processing Record 2 of Set 5 : dingle
# Processing Record 3 of Set 5 : paonta sahib
# Processing Record 4 of Set 5 : sheridan
# Processing Record 5 of Set 5 : lagoa da canoa
# Processing Record 6 of Set 5 : bethel
# Processing Record 7 of Set 5 : manado
# Processing Record 8 of Set 5 : lady frere
# Processing Record 9 of Set 5 : falkenberg
# Processing Record 10 of Set 5 : yambio
# Processing Record 11 of Set 5 : quarai
# Processing Record 12 of Set 5 : lagoa
# Processing Record 13 of Set 5 : ahuimanu
# Processing Record 14 of Set 5 : codrington
# Processing Record 15 of Set 5 : touros
# Processing Record 16 of Set 5 : beringovskiy
# Processing Record 17 of Set 5 : verkhnyaya tishanka
# Processing Record 18 of Set 5 : aksu
# Processing Record 19 of Set 5 : nenjiang
# Processing Record 20 of Set 5 : helong
# Processing Record 21 of Set 5 : souillac
# Processing Record 22 of Set 5 : port-cartier
# Processing Record 23 of Set 5 : ribeira grande
# Processing Record 24 of Set 5 : la primavera
# Processing Record 25 of Set 5 : sal rei
# Processing Record 26 of Set 5 : acapulco
# Processing Record 27 of Set 5 : correntina
# Processing Record 28 of Set 5 : pangnirtung
# Processing Record 29 of Set 5 : hokitika
# Processing Record 30 of Set 5 : aban
# Processing Record 31 of Set 5 : hirara
# Processing Record 32 of Set 5 : ucluelet
# Processing Record 33 of Set 5 : nhulunbuy
# Processing Record 34 of Set 5 : san patricio
# Processing Record 35 of Set 5 : susanville
# Processing Record 36 of Set 5 : nabire
# Processing Record 37 of Set 5 : sterling
# Processing Record 38 of Set 5 : atambua
# City not found. skipping to next........
# Processing Record 39 of Set 5 : russell
# Processing Record 40 of Set 5 : seryshevo
# Processing Record 41 of Set 5 : chapais
# City not found. skipping to next........
# Processing Record 42 of Set 5 : alofi
# Processing Record 43 of Set 5 : neustrelitz
# Processing Record 44 of Set 5 : porgera
# Processing Record 45 of Set 5 : taoudenni
# Processing Record 46 of Set 5 : port elizabeth
# Processing Record 47 of Set 5 : dawlatabad
# Processing Record 48 of Set 5 : barpeta
# Processing Record 49 of Set 5 : matola
# Processing Record 50 of Set 5 : krefeld
# Processing Record 0 of Set 6 : matara
# Processing Record 1 of Set 6 : huilong
# Processing Record 2 of Set 6 : motygino
# Processing Record 3 of Set 6 : hambantota
# Processing Record 4 of Set 6 : yulara
# Processing Record 5 of Set 6 : hofn
# Processing Record 6 of Set 6 : rorvik
# Processing Record 7 of Set 6 : aswan
# Processing Record 8 of Set 6 : filadelfia
# Processing Record 9 of Set 6 : ahipara
# Processing Record 10 of Set 6 : wuxue
# City not found. skipping to next........
# Processing Record 11 of Set 6 : vanimo
# City not found. skipping to next........
# Processing Record 12 of Set 6 : asfi
# Processing Record 13 of Set 6 : liberty
# Processing Record 14 of Set 6 : krutinka
# Processing Record 15 of Set 6 : vaitape
# Processing Record 16 of Set 6 : wasilla
# Processing Record 17 of Set 6 : carmelo
# Processing Record 18 of Set 6 : wajima
# Processing Record 19 of Set 6 : tomatlan
# Processing Record 20 of Set 6 : botou
# Processing Record 21 of Set 6 : concordia
# Processing Record 22 of Set 6 : passo fundo
# Processing Record 23 of Set 6 : kavieng
# Processing Record 24 of Set 6 : pravdinskiy
# Processing Record 25 of Set 6 : rawson
# Processing Record 26 of Set 6 : kobelyaky
# City not found. skipping to next........
# Processing Record 27 of Set 6 : norman wells
# City not found. skipping to next........
# Processing Record 28 of Set 6 : jalu
# Processing Record 29 of Set 6 : emerald
# Processing Record 30 of Set 6 : saint-denis
# Processing Record 31 of Set 6 : calama
# Processing Record 32 of Set 6 : lehututu
# Processing Record 33 of Set 6 : kholodnyy
# Processing Record 34 of Set 6 : nome
# Processing Record 35 of Set 6 : westport
# Processing Record 36 of Set 6 : norden
# Processing Record 37 of Set 6 : baruun-urt
# Processing Record 38 of Set 6 : beyneu
# Processing Record 39 of Set 6 : totness
# Processing Record 40 of Set 6 : yacuiba
# Processing Record 41 of Set 6 : ponta delgada
# Processing Record 42 of Set 6 : la palma
# Processing Record 43 of Set 6 : ruteng
# Processing Record 44 of Set 6 : lorengau
# City not found. skipping to next........
# Processing Record 45 of Set 6 : anadyr
# Processing Record 46 of Set 6 : kerava
# Processing Record 47 of Set 6 : eureka
# Processing Record 48 of Set 6 : leningradskiy
# Processing Record 49 of Set 6 : road town
# Processing Record 50 of Set 6 : graaff-reinet
# Processing Record 0 of Set 7 : klaksvik
# Processing Record 1 of Set 7 : akim swedru
# Processing Record 2 of Set 7 : nikolskoye
# Processing Record 3 of Set 7 : verkhoyansk
# Processing Record 4 of Set 7 : ambilobe
# Processing Record 5 of Set 7 : pitangui
# Processing Record 6 of Set 7 : woodward
# Processing Record 2 of Set 11 : taunggyi
# City not found. skipping to next........
# City not found. skipping to next........
# Processing Record 3 of Set 11 : mount isa
# Processing Record 4 of Set 11 : ancud
# Processing Record 5 of Set 11 : sinnamary
# City not found. skipping to next........
# City not found. skipping to next........
# Processing Record 6 of Set 11 : kasempa
# Processing Record 7 of Set 11 : nyurba
# City not found. skipping to next........
# Processing Record 8 of Set 11 : puerto madryn
# Processing Record 9 of Set 11 : le vauclin
# Processing Record 10 of Set 11 : nuuk
# City not found. skipping to next........
# City not found. skipping to next........
# Processing Record 11 of Set 11 : gaziantep
# Processing Record 12 of Set 11 : pilar
# Processing Record 13 of Set 11 : stornoway
# Processing Record 14 of Set 11 : otta
# Processing Record 15 of Set 11 : hearst
# City not found. skipping to next........
# Processing Record 16 of Set 11 : luderitz
# Processing Record 17 of Set 11 : katherine
# Processing Record 18 of Set 11 : sioux lookout
# Processing Record 19 of Set 11 : neuquen
# Processing Record 20 of Set 11 : sandwick
# Processing Record 21 of Set 11 : ballina
# Processing Record 22 of Set 11 : juruti
# Processing Record 23 of Set 11 : paso de los toros
# Processing Record 24 of Set 11 : nuevo progreso
# Processing Record 25 of Set 11 : svetlogorsk
# Processing Record 26 of Set 11 : moindou
# Processing Record 27 of Set 11 : cozumel
# Processing Record 28 of Set 11 : bonavista
# Processing Record 29 of Set 11 : ferkessedougou
# Processing Record 30 of Set 11 : riyadh
# ________________________________
# Data Retrieval Complets
# ________________________________

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Converting Raw Data into DataFrame
  #Create a dataframe using information obtained from data retrieval
weather_data = pd.DataFrame({
    "City" : city_name,
    "Lat" : lat,
    "Lng" : long,
    "Max Temp" : max_temp,
    "Humidity" : humidity,
    "Cloudiness" : cloud,
    "Wind Speed" : wind_speed,
    "Country" : country_name,
    "Date" : date    
})

# %%
#weather data count
weather_data.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
#Displaying dataframe
weather_data.head(540)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                    Tiksi  71.6872  128.8694    -10.71       100         100
# 1           Puerto Carreño   6.1890  -67.4859     86.99        33          65
# 2             Richards Bay -28.7830   32.0377     74.35        82          61
# 3                  Rikitea -23.1203 -134.9692     78.01        67          66
# 4              Port Alfred -33.5906   26.8910     74.95        96         100
# ..                     ...      ...       ...       ...       ...         ...
# 535                Moindou -21.6924  165.6770     78.75        67          96
# 536  San Miguel de Cozumel  20.5083  -86.9458     70.95        77          20
# 537              Bonavista  48.6499  -53.1147     32.11        70          63
# 538         Ferkessédougou   9.6000   -5.2000     74.23        15          32
# 539                 Riyadh  24.6877   46.7219     64.54        40          27
#
#      Wind Speed Country        Date
# 0          6.58      RU  1643674237
# 1          6.38      CO  1643674644
# 2          9.89      ZA  1643674645
# 3          4.72      PF  1643674646
# 4          5.82      ZA  1643674647
# ..          ...     ...         ...
# 535        5.75      NC  1643675086
# 536        3.00      MX  1643675048
# 537       15.37      CA  1643675088
# 538        4.94      CI  1643675088
# 539        7.05      SA  1643674845
#
# [540 rows x 9 columns]

# %%
#Exporting the City_Data into a csv
weather_data.to_csv("../output_data/cities.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_data[weather_data.Humidity>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
    #there are no cities with humidity >100 % in my retrived dataset see input "31" above and its output.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Latitude vs Temperature Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs Max Temperature (01/31/22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# Fig.1

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Latitude vs Humidity scatter plot

plt.scatter(weather_data["Lat"], weather_data["Humidity"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs Humidity (01/31/22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# Fig.2

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Latitude vs Cloudiness scatter plot
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs Cloudiness (01/31/22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# Fig.3

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs Wind Speed scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs Wind Speed (01/31/22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# Fig.4

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere(hemis) DataFrames

northern_hemis = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemis = weather_data.loc[weather_data["Lat"] < 0]

# %% [markdown]
# <b> Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Creating a function to create Linear Regression plots and adding the linear regression equation and line 
# Scatter Plot for Lattitude vs Temperature of City

x_values = northern_hemis['Lat']
y_values = northern_hemis['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(-5,100)
plt.xlim(0, 80)

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Temps at Lat_Positions_Northern Hemisphere')
plt.tight_layout()
plt.savefig("../Images/N_Hemis_Lat_vs_MaxTem.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
# Out:
# The r-squared is: -0.8562688869761063
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# Fig.5

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemis['Lat']
y_values = southern_hemis['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(40,100)
plt.xlim(-60,0)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Temps at Lat_Positions_Southern Hemisphere')
plt.tight_layout()
plt.savefig("../Images/S_Hemis_Lat_vs_MaxTem.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, temperature appears to be increasing as you get coser to the equator(0).")
# Out:
# The r-squared is: 0.26565903227845006
# The regression displays a positive correlation.
# In the southern hemisphere, temperature appears to be increasing as you get coser to the equator(0).

# %% [markdown]
# Fig.6

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemis["Lat"]
y_values = northern_hemis["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(0,110)
plt.xlim(0,80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Humidity (%) at Lat_Positions_N_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/N_Hemis_Lat_vs_Humidity.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the northern hemisphere, temperature appears to be increasing as latitude increases.")
# Out:
# The r-squared is: 0.41425511925778136
# The regression displays a positive correlation.
# In the northern hemisphere, temperature appears to be increasing as latitude increases.

# %% [markdown]
# Fig.7

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemis["Lat"]
y_values = southern_hemis["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-35,85),fontsize=15,color="red")

plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(0,110)
plt.xlim(0,-60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Humidity (%) at Lat_Positions_S_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/S_Hemis_Lat_vs_Humidity.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation but not strong relationship.")
print("In the northern hemisphere, temperature appears to be decreasing as you go away from the equator.")
# Out:
# The r-squared is: 0.4206674050116985
# The regression displays a positive correlation but not strong relationship.
# In the northern hemisphere, temperature appears to be decreasing as you go away from the equator.

# %% [markdown]
# Fig.8

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemis["Lat"]
y_values = northern_hemis["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-30,20),fontsize=15,color="red")

plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
# plt.show()

plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Coudiness(%) at Lat_Positions_N_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/N_Hemis_Lat_vs_Cloudiness.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the northern hemisphere,cloudiness appears to be increasing as you go away from the equator.")
# Out:
# The r-squared is: 0.3028528275060813
# The regression displays a positive correlation.
# In the northern hemisphere,cloudiness appears to be increasing as you go away from the equator.

# %% [markdown]
# Fig.9

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemis["Lat"]
y_values = southern_hemis["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")

plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(-5,105)
plt.xlim(-60,0)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Coudiness(%) at Lat_Positions_S_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/S_Hemis_Lat_vs_Cloudiness.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays a weak positive correlation.")
print("The regression does not show much of a correlation between the data sets")
# Out:
# The r-squared is: 0.2982502791151845
# The regression displays a weak positive correlation.
# The regression does not show much of a correlation between the data sets

# %% [markdown]
# Fig.10

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemis["Lat"]
y_values = northern_hemis["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(55,20),fontsize=15,color="red")

plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(0,40)
plt.xlim(0,80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Wind Speed(mph) at Lat_Positions_N_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/N_Hemis_Lat_vs_Wind_Speed.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays weak positive correlation.")
print("The regression does not show any correlation between the data sets")
# Out:
# The r-squared is: 0.11003790818482441
# The regression displays weak positive correlation.
# The regression does not show any correlation between the data sets

# %% [markdown]
# Fig.11

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemis["Lat"]
y_values = southern_hemis["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
# plt.show()
plt.ylim(-5,30)
plt.xlim(-60,0)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.title('Wind Speed(mph) at Lat_Positions_S_Hemisphere')
plt.tight_layout()
plt.savefig("../Images/S_Hemis_Lat_vs_Wind_Speed.png")

#print correlation coefficient
print(f"The r-squared is: {rvalue}")
print("The regression displays negative correlation.")
print("The regression does not show any correlation between the data sets")
# Out:
# The r-squared is: -0.14935084606605745
# The regression displays negative correlation.
# The regression does not show any correlation between the data sets

# %% [markdown]
# Fig.12
